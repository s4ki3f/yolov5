# %% [markdown]
# <a href="https://colab.research.google.com/github/s4ki3f/yolov5/blob/master/classify/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png"></a>
#
#
# <br>
#   <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/classify/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>See <a href="https://github.com/ultralytics/yolov5/issues/new/choose">GitHub</a> for community support or <a href="https://ultralytics.com/contact">contact us</a> for professional support.
#
# </div>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-3-g61ebf5e Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 22.6/78.2 GB disk)

# %% [markdown]
# # 1. Predict
#
# `classify/predict.py` runs YOLOv5 Classifcation inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/predict-cls`. Example inference sources are:
#
# ```shell
# python classify/predict.py --source 0  # webcam
#                               img.jpg  # image
#                               vid.mp4  # video
#                               screen  # screenshot
#                               path/  # directory
#                               'path/*.jpg'  # glob
#                               'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                               'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
import os
os.makedirs("../datasets/", exist_ok=True)
# %cd ../datasets/
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="deO5u1tP8oXg2HyoSRT4")
project = rf.workspace("tdc").project("cow-identification")
dataset = project.version(1).download("folder")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-0.2.22-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.8/dist-packages (from roboflow) (2022.12.7)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from roboflow) (3.2.2)
# Collecting urllib3==1.26.6
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 KB 18.7 MB/s eta 0:00:00
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: glob2 in /usr/local/lib/python3.8/dist-packages (from roboflow) (0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.64.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from roboflow) (6.0)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.25.1)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.21.6)
# Collecting python-dotenv
#   Downloading python_dotenv-0.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: opencv-python-headless>=4.5.1.48 in /usr/local/lib/python3.8/dist-packages (from roboflow) (4.6.0.66)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.8/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.8/dist-packages (from roboflow) (7.1.2)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=df760f286f7a6c17035f2f6cf8dcf78696ffb16d064d6a8cb7fc53b4d2bdc082
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget, urllib3, python-dotenv, pyparsing, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 pyparsing-2.4.7 python-dotenv-0.21.0 requests-toolbelt-0.10.1 roboflow-0.2.22 urllib3-1.26.6 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Cow-Identification-1 to folder: 100% [619492901 / 619492901] bytes
# Extracting Dataset Version Zip to Cow-Identification-1 in folder:: 100%|██████████| 6693/6693 [00:03<00:00, 1712.65it/s]

# %%
#Save the dataset name to the environment so we can use it in a system call later
dataset_name = dataset.location.split(os.sep)[-1]
os.environ["DATASET_NAME"] = dataset_name

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-cls' for x in p5]  # classification models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5n-cls.pt to weights/yolov5n-cls.pt...
#   0%|          | 0.00/4.87M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-cls.pt to weights/yolov5s-cls.pt...
#   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m-cls.pt to weights/yolov5m-cls.pt...
#   0%|          | 0.00/24.9M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l-cls.pt to weights/yolov5l-cls.pt...
#   0%|          | 0.00/50.9M [00:00<?, ?B/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5x-cls.pt to weights/yolov5x-cls.pt...
#   0%|          | 0.00/92.0M [00:00<?, ?B/s]

# %%
# !python classify/train.py --model yolov5x-cls.pt --data $DATASET_NAME  --epochs 100 --batch 64 --img 128
# Out:
# classify/train: model=yolov5x-cls.pt, data=Cow-Identification-1, epochs=100, batch_size=64, imgsz=128, nosave=False, cache=None, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=True, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-61-gcaba2ae Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
# albumentations: RandomResizedCrop(p=1.0, height=128, width=128, scale=(0.08, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[0, 0]), Normalize(p=1.0, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# Model summary: 338 layers, 47156906 parameters, 47156906 gradients, 129.8 GFLOPs
# optimizer: Adam(lr=0.001) with parameter groups 74 weight(decay=0.0), 75 weight(decay=5e-05), 75 bias
# Image sizes 128 train, 128 test
# Using 1 dataloader workers
# Logging results to runs/train-cls/exp2
# Starting yolov5x-cls.pt training on Cow-Identification-1 dataset with 266 classes for 100 epochs...
#
#      Epoch   GPU_mem  train_loss   test_loss    top1_acc    top5_acc
#      1/100     2.43G        4.15        8.32     0.00398       0.012: 100% 85/85 [00:42<00:00,  2.02it/s]
#      2/100     2.73G        2.71        8.56           0      0.0199: 100% 85/85 [00:40<00:00,  2.08it/s]
#      3/100     2.73G        2.21        8.43     0.00398       0.012: 100% 85/85 [00:41<00:00,  2.06it/s]
#     94/100     2.73G       0.961        8.01           0      0.0359: 100% 85/85 [00:40<00:00,  2.12it/s]
#     95/100     2.73G       0.961        8.01           0      0.0239: 100% 85/85 [00:40<00:00,  2.11it/s]
#     96/100     2.73G        0.96        8.01           0      0.0359: 100% 85/85 [00:41<00:00,  2.05it/s]
#     97/100     2.73G       0.959        8.03           0      0.0398: 100% 85/85 [00:40<00:00,  2.12it/s]
#     98/100     2.73G        0.95        8.02           0      0.0398: 100% 85/85 [00:40<00:00,  2.11it/s]
#     99/100     2.73G       0.954        7.99           0      0.0398: 100% 85/85 [00:40<00:00,  2.09it/s]
#    100/100     2.73G       0.948        7.98           0      0.0398: 100% 85/85 [00:41<00:00,  2.05it/s]
#
# Training complete (1.147 hours)
# Results saved to runs/train-cls/exp2
# Predict:         python classify/predict.py --weights runs/train-cls/exp2/weights/best.pt --source im.jpg
# Validate:        python classify/val.py --weights runs/train-cls/exp2/weights/best.pt --data /content/datasets/Cow-Identification-1
# Export:          python export.py --weights runs/train-cls/exp2/weights/best.pt --include onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'runs/train-cls/exp2/weights/best.pt')
# Visualize:       https://netron.app

# %%
# !python classify/val.py --weights runs/train-cls/exp2/weights/best.pt --data ../datasets/$DATASET_NAME
# Out:
# classify/val: data=../datasets/Cow-Identification-1, weights=['runs/train-cls/exp2/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-61-gcaba2ae Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 264 layers, 47132346 parameters, 0 gradients, 129.2 GFLOPs
# testing: 100% 2/2 [00:01<00:00,  1.04it/s]
#                    Class      Images    top1_acc    top5_acc
#                      all         251     0.00797       0.012
#              cattle_0100           1           0           0
#              cattle_0200           1           0           0
#              cattle_0300           1           0           0
#              cattle_0400           2           0           0
#              cattle_0500           1           0           0
#              cattle_0600           2           0           0
#              cattle_0700           1           0           0
#              cattle_0800           4           0           0
#              cattle_0900           1           0           0
#              cattle_1000           1           0           0
#              cattle_1100           3           0           0
#              cattle_1200           1           0           0
#              cattle_1300           2           0           0
#              cattle_1400           6           0           0
#              cattle_1500           8           0           0
#              cattle_1600           1           0           0
#              cattle_1700           1           0           0
#              cattle_1800           2           0           0
#              cattle_1900           2           0           0
#              cattle_2000           2           0           0
#              cattle_2100           1           0           0
#              cattle_2200           8           0           0
#              cattle_2220           2           0           0
#              cattle_2300           1           0           0
#              cattle_2320           1           0           0
#              cattle_2400           4           0           0
#              cattle_2500           2           0           0
#              cattle_2510           2           0           0
#              cattle_2600           1           0           0
#              cattle_2700           1           0           0
#              cattle_2710           2           0           0
#              cattle_2740           2           0           0
#              cattle_2800           1           0           0
#              cattle_2900           1           0           0
#              cattle_2930           1           0           0
#              cattle_3000           2           0           0
#              cattle_3100           1           0           0
#              cattle_3200           1           0           0
#              cattle_3300           2           0           0
#              cattle_3400           2           0           0
#              cattle_3420           1           0           0
#              cattle_3802           1           0           0
#              cattle_3812           8           0           0
#              cattle_3814           2           0           0
#              cattle_3819           2           0           0
#              cattle_3832           1           0           0
#              cattle_3842           3           0           0
#              cattle_3844           1           0           0
#              cattle_3847           1           0           0
#              cattle_3852           3           0           0
#              cattle_6295           0         nan         nan
#              cattle_6313           0         nan         nan
#              cattle_6331           0         nan         nan
#              cattle_6333           0         nan         nan
#              cattle_6442           0         nan         nan
#              cattle_6446           0         nan         nan
#              cattle_6458           0         nan         nan
#              cattle_6479           0         nan         nan
#              cattle_6499           0         nan         nan
#              cattle_6505           0         nan         nan
#              cattle_6506           0         nan         nan
#              cattle_6530           0         nan         nan
#              cattle_6606           0         nan         nan
#              cattle_8050           0         nan         nan
#              cattle_8094           0         nan         nan
#              cattle_8095           0         nan         nan
#              cattle_9021           0         nan         nan
#              cattle_9029           0         nan         nan
#              cattle_9634           0         nan         nan
#              cattle_9635           0         nan         nan
#              cattle_9736           0         nan         nan
#              cattle_9742           0         nan         nan
#              cattle_9773           0         nan         nan
#              cattle_9798           0         nan         nan
#              cattle_9801           0         nan         nan
# Speed: 0.1ms pre-process, 2.0ms inference, 0.0ms post-process per image at shape (1, 3, 224, 224)
# Results saved to runs/val-cls/exp2

# %%
# !python classify/predict.py --weights /content/yolov5/runs/train-cls/exp2/weights/best.pt --img 224 --source /content/datasets/Cow-Identification-1/test/cattle_3812/cattle_3812_DSCF1567_jpg.rf.10f7ce4a86622259efb3cfb21ab68e68.jpg
# display.Image(filename='runs/predict-cls/exp/zidane.jpg', width=600)
# Out:
# classify/predict: weights=['/content/yolov5/runs/train-cls/exp2/weights/best.pt'], source=/content/datasets/Cow-Identification-1/test/cattle_3812/cattle_3812_DSCF1567_jpg.rf.10f7ce4a86622259efb3cfb21ab68e68.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-61-gcaba2ae Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 264 layers, 47132346 parameters, 0 gradients, 129.2 GFLOPs
# image 1/1 /content/datasets/Cow-Identification-1/test/cattle_3812/cattle_3812_DSCF1567_jpg.rf.10f7ce4a86622259efb3cfb21ab68e68.jpg: 224x224 cattle_3812 0.47, cattle_5836 0.04, cattle_5427 0.03, cattle_4551 0.02, cattle_4804 0.01, 15.0ms
# Speed: 0.3ms pre-process, 15.0ms inference, 0.1ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp2

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/202808393-50deb439-ae1b-4246-a685-7560c9b37211.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [Imagenet](https://image-net.org/) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download Imagenet val (6.3G, 50000 images)
# !bash data/scripts/get_imagenet.sh --val
# Out:
# --2023-01-10 02:04:31--  https://image-net.org/data/ILSVRC/2012/ILSVRC2012_img_val.tar
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6744924160 (6.3G) [application/x-tar]
# Saving to: ‘ILSVRC2012_img_val.tar’
#
# ILSVRC2012_img_val.  13%[=>                  ] 854.95M  16.8MB/s    eta 5m 46s ^C

# %%
# Validate YOLOv5s on Imagenet val
# !python classify/val.py --weights yolov5s-cls.pt --data ../datasets/imagenet --img 224 --half
# Out:
# classify/val: data=../datasets/Cow-Identification-1/, weights=['yolov5s-cls.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-61-gcaba2ae Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary:
#                    snail           1           0           0
#                     slug           1           0           0
#                 sea slug           1           0           0
#                   chiton           1           0           0
#       chambered nautilus           1           0           0
#           Dungeness crab           1           0           0
#                rock crab           3           0           0
#             fiddler crab           1           0           0
#            red king crab           1           0           0
#         American lobster           0         nan         nan
#            spiny lobster           0         nan         nan
#                 crayfish           0         nan         nan
#              hermit crab           0         nan         nan
#                   isopod           0         nan         nan
#              white stork           0         nan         nan
#              black stork           0         nan         nan
#                spoonbill           0         nan         nan
#                 flamingo           0         nan         nan
#        little blue heron           0         nan         nan
#              great egret           0         nan         nan
#                  bittern           0         nan         nan
#             crane (bird)           0         nan         nan
#                  limpkin           0         nan         nan
#         common gallinule           0         nan         nan
#            American coot           0         nan         nan
#                  bustard           0         nan         nan
#          ruddy turnstone           0         nan         nan
#                   dunlin           0         nan         nan
#          common redshank           0         nan         nan
#                dowitcher           0         nan         nan
#            oystercatcher           0         nan         nan
#                  pelican           0         nan         nan
#             king penguin           0         nan         nan
#                albatross           0         nan         nan
#               grey whale           0         nan         nan
#             killer whale           0         nan         nan
#                   dugong           0         nan         nan
#                 sea lion           0         nan         nan
#                Chihuahua           0         nan         nan
#            Japanese Chin           0         nan         nan
#                  Maltese           0         nan         nan
#                Pekingese           0         nan         nan
#                 Shih Tzu           0         nan         nan
#     King Charles Spaniel           0         nan         nan
#                 Papillon           0         nan         nan
#              toy terrier           0         nan         nan
#      Rhodesian Ridgeback           0         nan         nan
#             Afghan Hound           0         nan         nan
#             Basset Hound           0         nan         nan
#                   Beagle           0         nan         nan
#               Bloodhound           0         nan         nan
#       Bluetick Coonhound           0         nan         nan
#  Black and Tan Coonhound           0         nan         nan
# Treeing Walker Coonhound           0         nan         nan
#         English foxhound           0         nan         nan
#        Redbone Coonhound           0         nan         nan
#                   borzoi           0         nan         nan
#          Irish Wolfhound           0         nan         nan
#        Italian Greyhound           0         nan         nan
#                  Whippet           0         nan         nan
#             Ibizan Hound           0         nan         nan
#       Norwegian Elkhound           0         nan         nan
#               Otterhound           0         nan         nan
#                   Saluki           0         nan         nan
#       Scottish Deerhound           0         nan         nan
#               Weimaraner           0         nan         nan
# Staffordshire Bull Terrier           0         nan         nan
# American Staffordshire Terrier           0         nan         nan
#       Bedlington Terrier           0         nan         nan
#           Border Terrier           0         nan         nan
#       Kerry Blue Terrier           0         nan         nan
#            Irish Terrier           0         nan         nan
#          Norfolk Terrier           0         nan         nan
#          Norwich Terrier           0         nan         nan
#        Yorkshire Terrier           0         nan         nan
#         Wire Fox Terrier           0         nan         nan
#         Lakeland Terrier           0         nan         nan
#         Sealyham Terrier           0         nan         nan
#         Airedale Terrier           0         nan         nan
#            Cairn Terrier           0         nan         nan
#       Australian Terrier           0         nan         nan
#   Dandie Dinmont Terrier           0         nan         nan
#           Boston Terrier           0         nan         nan
#      Miniature Schnauzer           0         nan         nan
#          Giant Schnauzer           0         nan         nan
#       Standard Schnauzer           0         nan         nan
#         Scottish Terrier           0         nan         nan
#          Tibetan Terrier           0         nan         nan
# Australian Silky Terrier           0         nan         nan
# Soft-coated Wheaten Terrier           0         nan         nan
# West Highland White Terrier           0         nan         nan
#               Lhasa Apso           0         nan         nan
#    Flat-Coated Retriever           0         nan         nan
#   Curly-coated Retriever           0         nan         nan
#         Golden Retriever           0         nan         nan
#       Labrador Retriever           0         nan         nan
# Chesapeake Bay Retriever           0         nan         nan
# German Shorthaired Pointer           0         nan         nan
#                   Vizsla           0         nan         nan
#           English Setter           0         nan         nan
#             Irish Setter           0         nan         nan
#            Gordon Setter           0         nan         nan
#                 Brittany           0         nan         nan
#          Clumber Spaniel           0         nan         nan
# English Springer Spaniel           0         nan         nan
#   Welsh Springer Spaniel           0         nan         nan
#          Cocker Spaniels           0         nan         nan
#           Sussex Spaniel           0         nan         nan
#      Irish Water Spaniel           0         nan         nan
#                   Kuvasz           0         nan         nan
#               Schipperke           0         nan         nan
#              Groenendael           0         nan         nan
#                 Malinois           0         nan         nan
#                   Briard           0         nan         nan
#        Australian Kelpie           0         nan         nan
#                 Komondor           0         nan         nan
#     Old English Sheepdog           0         nan         nan
#        Shetland Sheepdog           0         nan         nan
#                   collie           0         nan         nan
#            Border Collie           0         nan         nan
#     Bouvier des Flandres           0         nan         nan
#               Rottweiler           0         nan         nan
#      German Shepherd Dog           0         nan         nan
#                Dobermann           0         nan         nan
#       Miniature Pinscher           0         nan         nan
# Greater Swiss Mountain Dog           0         nan         nan
#     Bernese Mountain Dog           0         nan         nan
#   Appenzeller Sennenhund           0         nan         nan
#   Entlebucher Sennenhund           0         nan         nan
#                    Boxer           0         nan         nan
#              Bullmastiff           0         nan         nan
#          Tibetan Mastiff           0         nan         nan
#           French Bulldog           0         nan         nan
#               Great Dane           0         nan         nan
#              St. Bernard           0         nan         nan
#                    husky           0         nan         nan
#         Alaskan Malamute           0         nan         nan
#           Siberian Husky           0         nan         nan
#                Dalmatian           0         nan         nan
#            Affenpinscher           0         nan         nan
#                  Basenji           0         nan         nan
#                      pug           0         nan         nan
#               Leonberger           0         nan         nan
#             Newfoundland           0         nan         nan
#    Pyrenean Mountain Dog           0         nan         nan
#                  Samoyed           0         nan         nan
#               Pomeranian           0         nan         nan
#                Chow Chow           0         nan         nan
#                 Keeshond           0         nan         nan
#       Griffon Bruxellois           0         nan         nan
#     Pembroke Welsh Corgi           0         nan         nan
#     Cardigan Welsh Corgi           0         nan         nan
#               Toy Poodle           0         nan         nan
#         Miniature Poodle           0         nan         nan
#          Standard Poodle           0         nan         nan
#     Mexican hairless dog           0         nan         nan
#                grey wolf           0         nan         nan
#      Alaskan tundra wolf           0         nan         nan
#                 red wolf           0         nan         nan
#                   coyote           0         nan         nan
#                    dingo           0         nan         nan
#                    dhole           0         nan         nan
#         African wild dog           0         nan         nan
#                    hyena           0         nan         nan
#                  red fox           0         nan         nan
#                  kit fox           0         nan         nan
#               Arctic fox           0         nan         nan
#                 grey fox           0         nan         nan
#                tabby cat           0         nan         nan
#                tiger cat           0         nan         nan
#              Persian cat           0         nan         nan
#              Siamese cat           0         nan         nan
#             Egyptian Mau           0         nan         nan
#                   cougar           0         nan         nan
#                     lynx           0         nan         nan
#                  leopard           0         nan         nan
#             snow leopard           0         nan         nan
#                   jaguar           0         nan         nan
#                     lion           0         nan         nan
#                    tiger           0         nan         nan
#                  cheetah           0         nan         nan
#               brown bear           0         nan         nan
#      American black bear           0         nan         nan
#               polar bear           0         nan         nan
#               sloth bear           0         nan         nan
#                 mongoose           0         nan         nan
#                  meerkat           0         nan         nan
#             tiger beetle           0         nan         nan
#                  ladybug           0         nan         nan
#            ground beetle           0         nan         nan
#          longhorn beetle           0         nan         nan
#              leaf beetle           0         nan         nan
#              dung beetle           0         nan         nan
#        rhinoceros beetle           0         nan         nan
#                   weevil           0         nan         nan
#                      fly           0         nan         nan
#                      bee           0         nan         nan
#                      ant           0         nan         nan
#              grasshopper           0         nan         nan
#                  cricket           0         nan         nan
#             stick insect           0         nan         nan
#                cockroach           0         nan         nan
#                   mantis           0         nan         nan
#                   cicada           0         nan         nan
#               leafhopper           0         nan         nan
#                 lacewing           0         nan         nan
#                dragonfly           0         nan         nan
#                damselfly           0         nan         nan
#              red admiral           0         nan         nan
#                  ringlet           0         nan         nan
#        monarch butterfly           0         nan         nan
#              small white           0         nan         nan
#        sulphur butterfly           0         nan         nan
# gossamer-winged butterfly           0         nan         nan
#                 starfish           0         nan         nan
#               sea urchin           0         nan         nan
#             sea cucumber           0         nan         nan
#        cottontail rabbit           0         nan         nan
#                     hare           0         nan         nan
#            Angora rabbit           0         nan         nan
#                  hamster           0         nan         nan
#                porcupine           0         nan         nan
#             fox squirrel           0         nan         nan
#                   marmot           0         nan         nan
#                   beaver           0         nan         nan
#               guinea pig           0         nan         nan
#            common sorrel           0         nan         nan
#                    zebra           0         nan         nan
#                      pig           0         nan         nan
#                wild boar           0         nan         nan
#                  warthog           0         nan         nan
#             hippopotamus           0         nan         nan
#                       ox           0         nan         nan
#            water buffalo           0         nan         nan
#                    bison           0         nan         nan
#                      ram           0         nan         nan
#            bighorn sheep           0         nan         nan
#              Alpine ibex           0         nan         nan
#               hartebeest           0         nan         nan
#                   impala           0         nan         nan
#                  gazelle           0         nan         nan
#                dromedary           0         nan         nan
#                    llama           0         nan         nan
#                   weasel           0         nan         nan
#                     mink           0         nan         nan
#         European polecat           0         nan         nan
#      black-footed ferret           0         nan         nan
#                    otter           0         nan         nan
#                    skunk           0         nan         nan
#                   badger           0         nan         nan
#                armadillo           0         nan         nan
#         three-toed sloth           0         nan         nan
#                orangutan           0         nan         nan
#                  gorilla           0         nan         nan
#               chimpanzee           0         nan         nan
#                   gibbon           0         nan         nan
#                  siamang           0         nan         nan
#                   guenon           0         nan         nan
#             patas monkey           0         nan         nan
#                   baboon           0         nan         nan
#                  macaque           0         nan         nan
#                   langur           0         nan         nan
#  black-and-white colobus           0         nan         nan
#         proboscis monkey           0         nan         nan
#                 marmoset           0         nan         nan
#    white-headed capuchin           0         nan         nan
#            howler monkey           0         nan         nan
#                     titi           0         nan         nan
# Geoffroy's spider monkey           0         nan         nan
#   common squirrel monkey           0         nan         nan
#        ring-tailed lemur           0         nan         nan
#                    indri           0         nan         nan
#           Asian elephant           0         nan         nan
#    African bush elephant           0         nan         nan
#                red panda           0         nan         nan
#              giant panda           0         nan         nan
#                    snoek           0         nan         nan
#                      eel           0         nan         nan
#              coho salmon           0         nan         nan
#              rock beauty           0         nan         nan
#                clownfish           0         nan         nan
#                 sturgeon           0         nan         nan
#                  garfish           0         nan         nan
#                 lionfish           0         nan         nan
#               pufferfish           0         nan         nan
#                   abacus           0         nan         nan
#                    abaya           0         nan         nan
#            academic gown           0         nan         nan
#                accordion           0         nan         nan
#          acoustic guitar           0         nan         nan
#         aircraft carrier           0         nan         nan
#                 airliner           0         nan         nan
#                  airship           0         nan         nan
#                    altar           0         nan         nan
#                ambulance           0         nan         nan
#       amphibious vehicle           0         nan         nan
#             analog clock           0         nan         nan
#                   apiary           0         nan         nan
#                    apron           0         nan         nan
#          waste container           0         nan         nan
#            assault rifle           0         nan         nan
#                 backpack           0         nan         nan
#                   bakery           0         nan         nan
#             balance beam           0         nan         nan
#                  balloon           0         nan         nan
#            ballpoint pen           0         nan         nan
#                 Band-Aid           0         nan         nan
#                    banjo           0         nan         nan
#                 baluster           0         nan         nan
#                  barbell           0         nan         nan
#             barber chair           0         nan         nan
#               barbershop           0         nan         nan
#                     barn           0         nan         nan
#                barometer           0         nan         nan
#                   barrel           0         nan         nan
#              wheelbarrow           0         nan         nan
#                 baseball           0         nan         nan
#               basketball           0         nan         nan
#                 bassinet           0         nan         nan
#                  bassoon           0         nan         nan
#             swimming cap           0         nan         nan
#               bath towel           0         nan         nan
#                  bathtub           0         nan         nan
#            station wagon           0         nan         nan
#               lighthouse           0         nan         nan
#                   beaker           0         nan         nan
#             military cap           0         nan         nan
#              beer bottle           0         nan         nan
#               beer glass           0         nan         nan
#                 bell-cot           0         nan         nan
#                      bib           0         nan         nan
#           tandem bicycle           0         nan         nan
#                   bikini           0         nan         nan
#              ring binder           0         nan         nan
#               binoculars           0         nan         nan
#                birdhouse           0         nan         nan
#                boathouse           0         nan         nan
#                bobsleigh           0         nan         nan
#                 bolo tie           0         nan         nan
#              poke bonnet           0         nan         nan
#                 bookcase           0         nan         nan
#                bookstore           0         nan         nan
#               bottle cap           0         nan         nan
#                      bow           0         nan         nan
#                  bow tie           0         nan         nan
#                    brass           0         nan         nan
#                      bra           0         nan         nan
#               breakwater           0         nan         nan
#              breastplate           0         nan         nan
#                    broom           0         nan         nan
#                   bucket           0         nan         nan
#                   buckle           0         nan         nan
#         bulletproof vest           0         nan         nan
#         high-speed train           0         nan         nan
#             butcher shop           0         nan         nan
#                  taxicab           0         nan         nan
#                 cauldron           0         nan         nan
#                   candle           0         nan         nan
#                   cannon           0         nan         nan
#                    canoe           0         nan         nan
#               can opener           0         nan         nan
#                 cardigan           0         nan         nan
#               car mirror           0         nan         nan
#                 carousel           0         nan         nan
#                 tool kit           0         nan         nan
#                   carton           0         nan         nan
#                car wheel           0         nan         nan
# automated teller machine           0         nan         nan
#                 cassette           0         nan         nan
#          cassette player           0         nan         nan
#                   castle           0         nan         nan
#                catamaran           0         nan         nan
#                CD player           0         nan         nan
#                    cello           0         nan         nan
#             mobile phone           0         nan         nan
#                    chain           0         nan         nan
#         chain-link fence           0         nan         nan
#               chain mail           0         nan         nan
#                 chainsaw           0         nan         nan
#                    chest           0         nan         nan
#               chiffonier           0         nan         nan
#                    chime           0         nan         nan
#            china cabinet           0         nan         nan
#       Christmas stocking           0         nan         nan
#                   church           0         nan         nan
#            movie theater           0         nan         nan
#                  cleaver           0         nan         nan
#           cliff dwelling           0         nan         nan
#                    cloak           0         nan         nan
#                    clogs           0         nan         nan
#          cocktail shaker           0         nan         nan
#               coffee mug           0         nan         nan
#              coffeemaker           0         nan         nan
#                     coil           0         nan         nan
#         combination lock           0         nan         nan
#        computer keyboard           0         nan         nan
#      confectionery store           0         nan         nan
#           container ship           0         nan         nan
#              convertible           0         nan         nan
#                corkscrew           0         nan         nan
#                   cornet           0         nan         nan
#              cowboy boot           0         nan         nan
#               cowboy hat           0         nan         nan
#                   cradle           0         nan         nan
#          crane (machine)           0         nan         nan
#             crash helmet           0         nan         nan
#                    crate           0         nan         nan
#               infant bed           0         nan         nan
#                Crock Pot           0         nan         nan
#             croquet ball           0         nan         nan
#                   crutch           0         nan         nan
#                  cuirass           0         nan         nan
#                      dam           0         nan         nan
#                     desk           0         nan         nan
#         desktop computer           0         nan         nan
#    rotary dial telephone           0         nan         nan
#                   diaper           0         nan         nan
#            digital clock           0         nan         nan
#            digital watch           0         nan         nan
#             dining table           0         nan         nan
#                dishcloth           0         nan         nan
#               dishwasher           0         nan         nan
#               disc brake           0         nan         nan
#                     dock           0         nan         nan
#                 dog sled           0         nan         nan
#                     dome           0         nan         nan
#                  doormat           0         nan         nan
#             drilling rig           0         nan         nan
#                     drum           0         nan         nan
#                drumstick           0         nan         nan
#                 dumbbell           0         nan         nan
#               Dutch oven           0         nan         nan
#             electric fan           0         nan         nan
#          electric guitar           0         nan         nan
#      electric locomotive           0         nan         nan
#     entertainment center           0         nan         nan
#                 envelope           0         nan         nan
#         espresso machine           0         nan         nan
#              face powder           0         nan         nan
#              feather boa           0         nan         nan
#           filing cabinet           0         nan         nan
#                 fireboat           0         nan         nan
#              fire engine           0         nan         nan
#        fire screen sheet           0         nan         nan
#                 flagpole           0         nan         nan
#                    flute           0         nan         nan
#            folding chair           0         nan         nan
#          football helmet           0         nan         nan
#                 forklift           0         nan         nan
#                 fountain           0         nan         nan
#             fountain pen           0         nan         nan
#          four-poster bed           0         nan         nan
#              freight car           0         nan         nan
#              French horn           0         nan         nan
#               frying pan           0         nan         nan
#                 fur coat           0         nan         nan
#            garbage truck           0         nan         nan
#                 gas mask           0         nan         nan
#                 gas pump           0         nan         nan
#                   goblet           0         nan         nan
#                  go-kart           0         nan         nan
#                golf ball           0         nan         nan
#                golf cart           0         nan         nan
#                  gondola           0         nan         nan
#                     gong           0         nan         nan
#                     gown           0         nan         nan
#              grand piano           0         nan         nan
#               greenhouse           0         nan         nan
#                   grille           0         nan         nan
#            grocery store           0         nan         nan
#               guillotine           0         nan         nan
#                 barrette           0         nan         nan
#               hair spray           0         nan         nan
#               half-track           0         nan         nan
#                   hammer           0         nan         nan
#                   hamper           0         nan         nan
#               hair dryer           0         nan         nan
#       hand-held computer           0         nan         nan
#             handkerchief           0         nan         nan
#          hard disk drive           0         nan         nan
#                harmonica           0         nan         nan
#                     harp           0         nan         nan
#                harvester           0         nan         nan
#                  hatchet           0         nan         nan
#                  holster           0         nan         nan
#             home theater           0         nan         nan
#                honeycomb           0         nan         nan
#                     hook           0         nan         nan
#               hoop skirt           0         nan         nan
#           horizontal bar           0         nan         nan
#      horse-drawn vehicle           0         nan         nan
#                hourglass           0         nan         nan
#                     iPod           0         nan         nan
#             clothes iron           0         nan         nan
#          jack-o'-lantern           0         nan         nan
#                    jeans           0         nan         nan
#                     jeep           0         nan         nan
#                  T-shirt           0         nan         nan
#            jigsaw puzzle           0         nan         nan
#          pulled rickshaw           0         nan         nan
#                 joystick           0         nan         nan
#                   kimono           0         nan         nan
#                 knee pad           0         nan         nan
#                     knot           0         nan         nan
#                 lab coat           0         nan         nan
#                    ladle           0         nan         nan
#                lampshade           0         nan         nan
#          laptop computer           0         nan         nan
#               lawn mower           0         nan         nan
#                 lens cap           0         nan         nan
#              paper knife           0         nan         nan
#                  library           0         nan         nan
#                 lifeboat           0         nan         nan
#                  lighter           0         nan         nan
#                limousine           0         nan         nan
#              ocean liner           0         nan         nan
#                 lipstick           0         nan         nan
#             slip-on shoe           0         nan         nan
#                   lotion           0         nan         nan
#                  speaker           0         nan         nan
#                    loupe           0         nan         nan
#                  sawmill           0         nan         nan
#         magnetic compass           0         nan         nan
#                 mail bag           0         nan         nan
#                  mailbox           0         nan         nan
#                   tights           0         nan         nan
#                tank suit           0         nan         nan
#            manhole cover           0         nan         nan
#                   maraca           0         nan         nan
#                  marimba           0         nan         nan
#                     mask           0         nan         nan
#                    match           0         nan         nan
#                  maypole           0         nan         nan
#                     maze           0         nan         nan
#            measuring cup           0         nan         nan
#           medicine chest           0         nan         nan
#                 megalith           0         nan         nan
#               microphone           0         nan         nan
#           microwave oven           0         nan         nan
#         military uniform           0         nan         nan
#                 milk can           0         nan         nan
#                  minibus           0         nan         nan
#                miniskirt           0         nan         nan
#                  minivan           0         nan         nan
#                  missile           0         nan         nan
#                   mitten           0         nan         nan
#              mixing bowl           0         nan         nan
#              mobile home           0         nan         nan
#                  Model T           0         nan         nan
#                    modem           0         nan         nan
#                monastery           0         nan         nan
#                  monitor           0         nan         nan
#                    moped           0         nan         nan
#                   mortar           0         nan         nan
#      square academic cap           0         nan         nan
#                   mosque           0         nan         nan
#             mosquito net           0         nan         nan
#                  scooter           0         nan         nan
#            mountain bike           0         nan         nan
#                     tent           0         nan         nan
#           computer mouse           0         nan         nan
#                mousetrap           0         nan         nan
#               moving van           0         nan         nan
#                   muzzle           0         nan         nan
#                     nail           0         nan         nan
#               neck brace           0         nan         nan
#                 necklace           0         nan         nan
#                   nipple           0         nan         nan
#        notebook computer           0         nan         nan
#                  obelisk           0         nan         nan
#                     oboe           0         nan         nan
#                  ocarina           0         nan         nan
#                 odometer           0         nan         nan
#               oil filter           0         nan         nan
#                    organ           0         nan         nan
#             oscilloscope           0         nan         nan
#                overskirt           0         nan         nan
#             bullock cart           0         nan         nan
#              oxygen mask           0         nan         nan
#                   packet           0         nan         nan
#                   paddle           0         nan         nan
#             paddle wheel           0         nan         nan
#                  padlock           0         nan         nan
#               paintbrush           0         nan         nan
#                  pajamas           0         nan         nan
#                   palace           0         nan         nan
#                pan flute           0         nan         nan
#              paper towel           0         nan         nan
#                parachute           0         nan         nan
#            parallel bars           0         nan         nan
#               park bench           0         nan         nan
#            parking meter           0         nan         nan
#            passenger car           0         nan         nan
#                    patio           0         nan         nan
#                 payphone           0         nan         nan
#                 pedestal           0         nan         nan
#              pencil case           0         nan         nan
#         pencil sharpener           0         nan         nan
#                  perfume           0         nan         nan
#               Petri dish           0         nan         nan
#              photocopier           0         nan         nan
#                 plectrum           0         nan         nan
#              Pickelhaube           0         nan         nan
#             picket fence           0         nan         nan
#             pickup truck           0         nan         nan
#                     pier           0         nan         nan
#               piggy bank           0         nan         nan
#              pill bottle           0         nan         nan
#                   pillow           0         nan         nan
#           ping-pong ball           0         nan         nan
#                 pinwheel           0         nan         nan
#              pirate ship           0         nan         nan
#                  pitcher           0         nan         nan
#               hand plane           0         nan         nan
#              planetarium           0         nan         nan
#              plastic bag           0         nan         nan
#               plate rack           0         nan         nan
#                     plow           0         nan         nan
#                  plunger           0         nan         nan
#          Polaroid camera           0         nan         nan
#                     pole           0         nan         nan
#               police van           0         nan         nan
#                   poncho           0         nan         nan
#           billiard table           0         nan         nan
#              soda bottle           0         nan         nan
#                      pot           0         nan         nan
#           potter's wheel           0         nan         nan
#              power drill           0         nan         nan
#               prayer rug           0         nan         nan
#                  printer           0         nan         nan
#                   prison           0         nan         nan
#               projectile           0         nan         nan
#                projector           0         nan         nan
#              hockey puck           0         nan         nan
#             punching bag           0         nan         nan
#                    purse           0         nan         nan
#                    quill           0         nan         nan
#                    quilt           0         nan         nan
#                 race car           0         nan         nan
#                   racket           0         nan         nan
#                 radiator           0         nan         nan
#                    radio           0         nan         nan
#          radio telescope           0         nan         nan
#              rain barrel           0         nan         nan
#     recreational vehicle           0         nan         nan
#                     reel           0         nan         nan
#            reflex camera           0         nan         nan
#             refrigerator           0         nan         nan
#           remote control           0         nan         nan
#               restaurant           0         nan         nan
#                 revolver           0         nan         nan
#                    rifle           0         nan         nan
#            rocking chair           0         nan         nan
#               rotisserie           0         nan         nan
#                   eraser           0         nan         nan
#               rugby ball           0         nan         nan
#                    ruler           0         nan         nan
#             running shoe           0         nan         nan
#                     safe           0         nan         nan
#               safety pin           0         nan         nan
#              salt shaker           0         nan         nan
#                   sandal           0         nan         nan
#                   sarong           0         nan         nan
#                saxophone           0         nan         nan
#                 scabbard           0         nan         nan
#           weighing scale           0         nan         nan
#               school bus           0         nan         nan
#                 schooner           0         nan         nan
#               scoreboard           0         nan         nan
#               CRT screen           0         nan         nan
#                    screw           0         nan         nan
#              screwdriver           0         nan         nan
#                seat belt           0         nan         nan
#           sewing machine           0         nan         nan
#                   shield           0         nan         nan
#               shoe store           0         nan         nan
#                    shoji           0         nan         nan
#          shopping basket           0         nan         nan
#            shopping cart           0         nan         nan
#                   shovel           0         nan         nan
#               shower cap           0         nan         nan
#           shower curtain           0         nan         nan
#                      ski           0         nan         nan
#                 ski mask           0         nan         nan
#             sleeping bag           0         nan         nan
#               slide rule           0         nan         nan
#             sliding door           0         nan         nan
#             slot machine           0         nan         nan
#                  snorkel           0         nan         nan
#               snowmobile           0         nan         nan
#                 snowplow           0         nan         nan
#           soap dispenser           0         nan         nan
#              soccer ball           0         nan         nan
#                     sock           0         nan         nan
#  solar thermal collector           0         nan         nan
#                 sombrero           0         nan         nan
#                soup bowl           0         nan         nan
#                space bar           0         nan         nan
#             space heater           0         nan         nan
#            space shuttle           0         nan         nan
#                  spatula           0         nan         nan
#                motorboat           0         nan         nan
#               spider web           0         nan         nan
#                  spindle           0         nan         nan
#               sports car           0         nan         nan
#                spotlight           0         nan         nan
#                    stage           0         nan         nan
#         steam locomotive           0         nan         nan
#      through arch bridge           0         nan         nan
#               steel drum           0         nan         nan
#              stethoscope           0         nan         nan
#                    scarf           0         nan         nan
#               stone wall           0         nan         nan
#                stopwatch           0         nan         nan
#                    stove           0         nan         nan
#                 strainer           0         nan         nan
#                     tram           0         nan         nan
#                stretcher           0         nan         nan
#                    couch           0         nan         nan
#                    stupa           0         nan         nan
#                submarine           0         nan         nan
#                     suit           0         nan         nan
#                  sundial           0         nan         nan
#                 sunglass           0         nan         nan
#               sunglasses           0         nan         nan
#                sunscreen           0         nan         nan
#        suspension bridge           0         nan         nan
#                      mop           0         nan         nan
#               sweatshirt           0         nan         nan
#                 swimsuit           0         nan         nan
#                    swing           0         nan         nan
#                   switch           0         nan         nan
#                  syringe           0         nan         nan
#               table lamp           0         nan         nan
#                     tank           0         nan         nan
#              tape player           0         nan         nan
#                   teapot           0         nan         nan
#               teddy bear           0         nan         nan
#               television           0         nan         nan
#              tennis ball           0         nan         nan
#            thatched roof           0         nan         nan
#            front curtain           0         nan         nan
#                  thimble           0         nan         nan
#        threshing machine           0         nan         nan
#                   throne           0         nan         nan
#                tile roof           0         nan         nan
#                  toaster           0         nan         nan
#             tobacco shop           0         nan         nan
#              toilet seat           0         nan         nan
#                    torch           0         nan         nan
#               totem pole           0         nan         nan
#                tow truck           0         nan         nan
#                toy store           0         nan         nan
#                  tractor           0         nan         nan
#       semi-trailer truck           0         nan         nan
#                     tray           0         nan         nan
#              trench coat           0         nan         nan
#                 tricycle           0         nan         nan
#                 trimaran           0         nan         nan
#                   tripod           0         nan         nan
#           triumphal arch           0         nan         nan
#               trolleybus           0         nan         nan
#                 trombone           0         nan         nan
#                      tub           0         nan         nan
#                turnstile           0         nan         nan
#      typewriter keyboard           0         nan         nan
#                 umbrella           0         nan         nan
#                 unicycle           0         nan         nan
#            upright piano           0         nan         nan
#           vacuum cleaner           0         nan         nan
#                     vase           0         nan         nan
#                    vault           0         nan         nan
#                   velvet           0         nan         nan
#          vending machine           0         nan         nan
#                 vestment           0         nan         nan
#                  viaduct           0         nan         nan
#                   violin           0         nan         nan
#               volleyball           0         nan         nan
#              waffle iron           0         nan         nan
#               wall clock           0         nan         nan
#                   wallet           0         nan         nan
#                 wardrobe           0         nan         nan
#        military aircraft           0         nan         nan
#                     sink           0         nan         nan
#          washing machine           0         nan         nan
#             water bottle           0         nan         nan
#                water jug           0         nan         nan
#              water tower           0         nan         nan
#              whiskey jug           0         nan         nan
#                  whistle           0         nan         nan
#                      wig           0         nan         nan
#            window screen           0         nan         nan
#             window shade           0         nan         nan
#              Windsor tie           0         nan         nan
#              wine bottle           0         nan         nan
#                     wing           0         nan         nan
#                      wok           0         nan         nan
#             wooden spoon           0         nan         nan
#                     wool           0         nan         nan
#         split-rail fence           0         nan         nan
#                shipwreck           0         nan         nan
#                     yawl           0         nan         nan
#                     yurt           0         nan         nan
#                  website           0         nan         nan
#               comic book           0         nan         nan
#                crossword           0         nan         nan
#             traffic sign           0         nan         nan
#            traffic light           0         nan         nan
#              dust jacket           0         nan         nan
#                     menu           0         nan         nan
#                    plate           0         nan         nan
#                guacamole           0         nan         nan
#                 consomme           0         nan         nan
#                  hot pot           0         nan         nan
#                   trifle           0         nan         nan
#                ice cream           0         nan         nan
#                  ice pop           0         nan         nan
#                 baguette           0         nan         nan
#                    bagel           0         nan         nan
#                  pretzel           0         nan         nan
#             cheeseburger           0         nan         nan
#                  hot dog           0         nan         nan
#            mashed potato           0         nan         nan
#                  cabbage           0         nan         nan
#                 broccoli           0         nan         nan
#              cauliflower           0         nan         nan
#                 zucchini           0         nan         nan
#         spaghetti squash           0         nan         nan
#             acorn squash           0         nan         nan
#         butternut squash           0         nan         nan
#                 cucumber           0         nan         nan
#                artichoke           0         nan         nan
#              bell pepper           0         nan         nan
#                  cardoon           0         nan         nan
#                 mushroom           0         nan         nan
#             Granny Smith           0         nan         nan
#               strawberry           0         nan         nan
#                   orange           0         nan         nan
#                    lemon           0         nan         nan
#                      fig           0         nan         nan
#                pineapple           0         nan         nan
#                   banana           0         nan         nan
#                jackfruit           0         nan         nan
#            custard apple           0         nan         nan
#              pomegranate           0         nan         nan
#                      hay           0         nan         nan
#                carbonara           0         nan         nan
#          chocolate syrup           0         nan         nan
#                    dough           0         nan         nan
#                 meatloaf           0         nan         nan
#                    pizza           0         nan         nan
#                  pot pie           0         nan         nan
#                  burrito           0         nan         nan
#                 red wine           0         nan         nan
#                 espresso           0         nan         nan
#                      cup           0         nan         nan
#                   eggnog           0         nan         nan
#                      alp           0         nan         nan
#                   bubble           0         nan         nan
#                    cliff           0         nan         nan
#               coral reef           0         nan         nan
#                   geyser           0         nan         nan
#                lakeshore           0         nan         nan
#               promontory           0         nan         nan
#                    shoal           0         nan         nan
#                 seashore           0         nan         nan
#                   valley           0         nan         nan
#                  volcano           0         nan         nan
#          baseball player           0         nan         nan
#               bridegroom           0         nan         nan
#              scuba diver           0         nan         nan
#                 rapeseed           0         nan         nan
#                    daisy           0         nan         nan
#    yellow lady's slipper           0         nan         nan
#                     corn           0         nan         nan
#                    acorn           0         nan         nan
#                 rose hip           0         nan         nan
#      horse chestnut seed           0         nan         nan
#             coral fungus           0         nan         nan
#                   agaric           0         nan         nan
#                gyromitra           0         nan         nan
#       stinkhorn mushroom           0         nan         nan
#               earth star           0         nan         nan
#         hen-of-the-woods           0         nan         nan
#                   bolete           0         nan         nan
#                      ear           0         nan         nan
#             toilet paper           0         nan         nan
# Speed: 0.1ms pre-process, 1.2ms inference, 0.0ms post-process per image at shape (1, 3, 224, 224)
# Results saved to runs/val-cls/exp3

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s Classification model on the [Imagenette](https://image-net.org/) dataset with `--data imagenet`, starting from pretrained `--pretrained yolov5s-cls.pt`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **Training Results** are saved to `runs/train-cls/` with incrementing run directories, i.e. `runs/train-cls/exp2`, `runs/train-cls/exp3` etc.
# <br><br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/train-yolov5-classification-custom-data/](https://blog.roboflow.com/train-yolov5-classification-custom-data/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1KZiKUAjtARHAfZCXbJRv14-pOnIsBLPV?usp=sharing)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://user-images.githubusercontent.com/26833433/202802162-92e60571-ab58-4409-948d-b31fddcd3c6f.png"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'TensorBoard' #@param ['TensorBoard', 'Comet', 'ClearML']

if logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
elif logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  import clearml; clearml.browser_login()

# %%
# Train YOLOv5s Classification on Imagenette160 for 3 epochs
# !python classify/train.py --model yolov5s-cls.pt --data imagenette160 --epochs 5 --img 224 --cache
# Out:
# classify/train: model=yolov5s-cls.pt, data=imagenette160, epochs=5, batch_size=64, imgsz=224, nosave=False, cache=ram, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=True, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-3-g61ebf5e Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
#
# Dataset not found ⚠️, missing path /content/datasets/imagenette160, attempting download...
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/imagenette160.zip to /content/datasets/imagenette160.zip...
# 100% 103M/103M [00:00<00:00, 347MB/s]
# Unzipping /content/datasets/imagenette160.zip...
# Dataset download success ✅ (3.3s), saved to /content/datasets/imagenette160
#
# albumentations: RandomResizedCrop(p=1.0, height=224, width=224, scale=(0.08, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[0, 0]), Normalize(p=1.0, mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# Model summary: 149 layers, 4185290 parameters, 4185290 gradients, 10.5 GFLOPs
# optimizer: Adam(lr=0.001) with parameter groups 32 weight(decay=0.0), 33 weight(decay=5e-05), 33 bias
# Image sizes 224 train, 224 test
# Using 1 dataloader workers
# Logging results to runs/train-cls/exp
# Starting yolov5s-cls.pt training on imagenette160 dataset with 10 classes for 5 epochs...
#
#      Epoch   GPU_mem  train_loss    val_loss    top1_acc    top5_acc
#        1/5     1.47G        1.05       0.974       0.828       0.975: 100% 148/148 [00:38<00:00,  3.82it/s]
#        2/5     1.73G       0.895       0.766       0.911       0.994: 100% 148/148 [00:36<00:00,  4.03it/s]
#        3/5     1.73G        0.82       0.704       0.934       0.996: 100% 148/148 [00:35<00:00,  4.20it/s]
#        4/5     1.73G       0.766       0.664       0.951       0.998: 100% 148/148 [00:36<00:00,  4.05it/s]
#        5/5     1.73G       0.724       0.634       0.959       0.997: 100% 148/148 [00:37<00:00,  3.94it/s]
#
# Training complete (0.052 hours)
# Results saved to runs/train-cls/exp
# Predict:         python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source im.jpg
# Validate:        python classify/val.py --weights runs/train-cls/exp/weights/best.pt --data /content/datasets/imagenette160
# Export:          python export.py --weights runs/train-cls/exp/weights/best.pt --include onnx
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', 'runs/train-cls/exp/weights/best.pt')
# Visualize:       https://netron.app

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://github.com/ultralytics/yolov5/tree/master/utils/loggers/comet). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://github.com/ultralytics/yolov5/tree/master/utils/loggers/clearml) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # yolov5n - yolov5x6 or custom
im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
